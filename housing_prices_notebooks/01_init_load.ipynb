# %% [markdown]
# ## 01 - Initial Data Load & Optimization
#
# **Project:** UK Housing Price Paid Records
#
# **Purpose:** To find the optimal way to load the large 2.4GB CSV file using memory and speed optimizations (`dtype` definition, `parse_dates`). The output of this notebook is the first, basic Parquet file.
#
# **Team Member(s):** Tymo Verhaegen
#
# **Date Last Run:** 07/11/2025
#
# ---

# %%
import pandas as pd
import os

# --- 1. Define Paths ---
csv_file_path = '../data/housing/price_paid_records.csv'
parquet_dir = '../data/housing/processed'
parquet_file_path = os.path.join(parquet_dir, 'price_paid_init.parquet')

# Create the processed directory if it doesn't exist
os.makedirs(parquet_dir, exist_ok=True)

# --- 2. Define Optimal Data Types (The Speed Hack) ---
# I added the missing address columns (Postcode, Street, Locality, PAON, SAON)
# so they don't get dropped or consume too much memory.
data_types = {
    'Transaction unique identifier': 'string',
    'Price': 'int32',
    'Date of Transfer': 'string',  # We parse this separately, but safe to define
    'Property Type': 'category',
    'Old/New': 'category',
    'Duration': 'category',
    'Street': 'string',
    'Town/City': 'category',
    'District': 'category',
    'County': 'category',
    'PPDCategory Type': 'category',
    'Record Status - monthly file only': 'category'
}

# --- 3. LOAD THE RAW DATA ---
print("Starting initial (slow) CSV load...")

try:
    df_raw = pd.read_csv(
        csv_file_path, 
        dtype=data_types,
        parse_dates=['Date of Transfer'], 
        # Note: If your CSV doesn't have headers, remove 'header=0' and add 'names=data_types.keys()'
        header=0, 
        low_memory=False, 
        engine='c'
    )
    print(f"CSV load complete! Loaded {len(df_raw):,} records.")
    
    # Quick sanity check to print columns
    print("Columns loaded:", df_raw.columns.tolist())

    # --- 4. SAVE AS OPTIMIZED PARQUET FILE ---
    print("Saving the optimized DataFrame to Parquet...")
    
    df_raw.to_parquet(parquet_file_path, index=False)
    
    print(f"\nSUCCESS! Optimized data saved to:\n{parquet_file_path}")
    
except FileNotFoundError:
    print(f"\nERROR: File not found at {csv_file_path}. Please check your path!")
except Exception as e:
    print(f"\nAn error occurred during loading/saving: {e}")
# Out:
# Starting initial (slow) CSV load...
# CSV load complete! Loaded 22,489,348 records.
# Columns loaded: ['Transaction unique identifier', 'Price', 'Date of Transfer', 'Property Type', 'Old/New', 'Duration', 'Town/City', 'District', 'County', 'PPDCategory Type', 'Record Status - monthly file only']
# Saving the optimized DataFrame to Parquet...
#
# SUCCESS! Optimized data saved to:
# ../data/housing/processed\price_paid_init.parquet
