# %% [markdown]
# ## 02 - Exploratory Data Analysis (EDA) and Initial Cleaning
#
# **Project:** UK Housing Price Paid Records
#
# **Purpose:** To explore the data structure, confirm data quality, identify and justify handling of outliers (e.g., non-market sales), create necessary features (Sale\_Year), and generate visualizations and correlations to inform the final model.
#
# **Team Member(s):** Tymo Verhaegen
#
# **Cleaning Decisions Made Here:**
# * Confirmed the absence of missing values.
# * Filtered out all non-market transactions where `price <= £1`.
# * Decided on renaming all columns to Python-friendly `snake_case`.
#
# **Date Last Run:** 06/11/2025
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Adjust settings for nicer plots
sns.set_style("whitegrid")
pd.set_option('display.max_columns', None)

# Load your raw parquet file (from step 01)
# Assuming filename is 'uk_housing_raw.parquet'
df = pd.read_parquet('./../data/housing/processed/price_paid_init.parquet')

# Check the size
print(f"Shape of full dataset: {df.shape}")

# CREATE A SAMPLE FOR EDA (Very Important for speed)
# We will design our cleaning rules on the sample, but apply logic thinking of the full set
df_sample = df.sample(frac=0.05, random_state=42).copy() 
print(f"Shape of sample dataset: {df_sample.shape}")
# Out:
# Shape of full dataset: (22489348, 11)
# Shape of sample dataset: (1124467, 11)

# %%
# Create a mapping or just use string manipulation
def clean_column_names(dataframe):
    dataframe.columns = dataframe.columns.str.lower().str.replace(' ', '_').str.replace('/', '_')
    return dataframe

df_sample = clean_column_names(df_sample)

# Display new names
print(df_sample.columns)
# Out:
# Index(['transaction_unique_identifier', 'price', 'date_of_transfer',
#        'property_type', 'old_new', 'duration', 'town_city', 'district',
#        'county', 'ppdcategory_type', 'record_status_-_monthly_file_only'],
#       dtype='object')

# %%
# Check missing percentage
missing_percent = df_sample.isnull().mean() * 100
print(missing_percent[missing_percent > 0])

# Visualizing missing data (Heatmap)
plt.figure(figsize=(10, 6))
sns.heatmap(df_sample.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()
# Out:
# Series([], dtype: float64)

# %%
# Outlier Analysis
print("\n--- Price Statistics ---")
print(df_sample['price'].describe())

# Visualizing Price Distribution
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.boxplot(x=df_sample['price'])
plt.title("Raw Price Boxplot (Log Scale recommended)")
plt.xscale('log') # Log scale because house prices vary wildly

plt.subplot(1, 2, 2)
# Histogram filtering extreme outliers for readability
subset_price = df_sample[(df_sample['price'] > 1000) & (df_sample['price'] < 2000000)]
sns.histplot(subset_price['price'], bins=50, kde=True)
plt.title("Price Histogram (£1k - £2m range)")
plt.show()
# Out:
# --- Price Statistics ---
# count    1.124467e+06
# mean     1.782073e+05
# std      3.591571e+05
# min      1.000000e+00
# 25%      7.500000e+04
# 50%      1.300000e+05
# 75%      2.100000e+05
# max      8.745942e+07
# Name: price, dtype: float64

# %%
# --- 6. FEATURE ENGINEERING & CATEGORICALS ---
print("\n--- Feature Analysis ---")

# A. Date Features
# Ensure date is datetime
df_sample['date_of_transfer'] = pd.to_datetime(df_sample['date_of_transfer'])
df_sample['year'] = df_sample['date_of_transfer'].dt.year
df_sample['month'] = df_sample['date_of_transfer'].dt.month

# B. Property Type Analysis
# D = Detached, S = Semi-Detached, T = Terraced, F = Flats, O = Other
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_sample, x='property_type', y='price', showfliers=False) 
# showfliers=False hides the dots so you can see the box clearly
plt.title("Price Distribution by Property Type (Outliers Hidden)")
plt.yscale('log')
plt.show()

# C. Trend Over Time
# We group by year to see the trend
yearly_avg = df_sample.groupby('year')['price'].mean().reset_index()

plt.figure(figsize=(12, 5))
sns.lineplot(data=yearly_avg, x='year', y='price', marker='o')
plt.title("Average House Price Trend (England & Wales)")
plt.ylabel("Average Price (£)")
plt.grid(True)
plt.show()

# D. Old vs New
plt.figure(figsize=(8, 5))
sns.boxplot(data=df_sample, x='old_new', y='price', showfliers=False)
plt.title("Price: Old vs New Builds")
plt.yscale('log')
plt.show()
# Out:
# --- Feature Analysis ---

# %%
# --- 7. CORRELATION MATRIX ---
# We convert categoricals to codes temporarily to check for correlations
df_corr = df_sample.copy()
cols_to_encode = ['property_type', 'old_new', 'duration', 'town_city', 'county']

for col in cols_to_encode:
    if col in df_corr.columns:
        df_corr[col] = df_corr[col].astype('category').cat.codes

# Select strictly numeric columns + encoded ones
numeric_cols = ['price', 'year', 'month'] + [c for c in cols_to_encode if c in df_corr.columns]
corr_matrix = df_corr[numeric_cols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
